# %%
import pandas as pd
from utilities import clean_data

# %%
df, df_brands, df_allbrands, brands, compsets, compset_groups, groups_bycompset = clean_data()

# %%
df
# Out:
#        period_end_date business_entity_doing_business_as_name  followers  \
# 239152      2017-05-06                                    24S       -1.0
# 239162      2017-05-13                                    24S       -1.0
# 239538      2017-05-20                                    24S       -1.0
# 239200      2017-05-27                                    24S       -1.0
# 239161      2017-06-03                                    24S       -1.0
# ...                ...                                    ...        ...
# 647869      2023-08-19                             shopDisney  4221812.0
# 647742      2023-08-26                             shopDisney  4224473.0
# 647803      2023-09-02                             shopDisney  4228605.0
# 647623      2023-09-09                             shopDisney  4233764.0
# 647704      2023-09-16                             shopDisney  4239207.0
#
#         pictures  videos  comments     likes
# 239152      -1.0    -1.0      -1.0      -1.0
# 239162       6.0     3.0      57.0    1765.0
# 239538       6.0     3.0      57.0    1765.0
# 239200       6.0     3.0      57.0    1765.0
# 239161      24.0     3.0     109.0    3922.0
# ...          ...     ...       ...       ...
# 647869     266.0    52.0    3099.0  266166.0
# 647742     265.0    61.0    3494.0  316126.0
# 647803     268.0    61.0    3920.0  341795.0
# 647623     259.0    56.0    3700.0  335231.0
# 647704     244.0    72.0    3908.0  330793.0
#
# [298040 rows x 7 columns]
