# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = '/Users/jonasspiller/Documents/STEM/Datathlon/data/skylab_instagram_datathon_dataset.csv'
df = pd.read_csv(file_path, header=0, sep=";")

# %%
df.head()
# Out:
#    period period_end_date                  compset_group  \
# 0  Weekly      2019-12-07  Luxury & Premium & Mainstream
# 1  Weekly      2021-01-30  Luxury & Premium & Mainstream
# 2  Weekly      2016-05-14  Luxury & Premium & Mainstream
# 3  Weekly      2019-04-20  Luxury & Premium & Mainstream
# 4  Weekly      2023-03-25  Luxury & Premium & Mainstream
#
#                               compset business_entity_doing_business_as_name  \
# 0                         Soft Luxury                                Versace
# 1       Luxury & Premium & Mainstream                                Versace
# 2                         Soft Luxury                                Versace
# 3       Luxury & Premium & Mainstream                                Versace
# 4  US Softlines Analyst Interest List                                Versace
#
#   legal_entity_name     domicile_country_name  \
# 0    Capri Holdings  United States of America
# 1    Capri Holdings  United States of America
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704313 entries, 0 to 704312
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   period                                  704313 non-null  object
#  1   period_end_date                         704313 non-null  object
#  2   compset_group                           704313 non-null  object
#  3   compset                                 704313 non-null  object
#  4   business_entity_doing_business_as_name  704313 non-null  object
#  5   legal_entity_name                       676558 non-null  object
#  6   domicile_country_name                   458589 non-null  object
#  7   ultimate_parent_legal_entity_name       676558 non-null  object
#  8   primary_exchange_name                   458589 non-null  object
#  9   calculation_type                        704313 non-null  object
# ...

# %%
df.describe()
# Out:
#           followers       pictures         videos      comments         likes
# count  5.792580e+05  695803.000000  684349.000000  6.953430e+05  6.959770e+05
# mean   1.342432e+07     344.272540      61.244426  3.043246e+04  2.163189e+06
# std    1.106975e+08    2777.396873     564.468480  2.766459e+05  1.803193e+07
# min    0.000000e+00       0.000000       0.000000  0.000000e+00  0.000000e+00
# 25%    3.013372e+05      19.000000       2.000000  3.710000e+02  1.727700e+04
# 50%    1.104144e+06      44.000000       7.000000  1.435000e+03  9.318400e+04
# 75%    4.479325e+06     122.000000      20.000000  5.872000e+03  4.577470e+05
# max    3.502565e+09  141746.000000   35905.000000  1.732046e+07  7.120711e+08

# %%
df.loc[df['followers'].idxmax()]
# Out:
# period                                                Weekly
# period_end_date                                   2023-09-16
# compset_group                             Study (All Brands)
# compset                                   Study (All Brands)
# business_entity_doing_business_as_name            All Brands
# legal_entity_name                                        NaN
# domicile_country_name                                    NaN
# ultimate_parent_legal_entity_name                        NaN
# primary_exchange_name                                    NaN
# calculation_type                                Metric Value
# followers                                       3502564772.0
# pictures                                             54562.0
# videos                                               35610.0
# comments                                           3797174.0
# likes                                            222471223.0
# Name: 367345, dtype: object

# %%
# First few entries for Versace
df[(df['business_entity_doing_business_as_name'] == 'Versace')].sort_values(by='period_end_date')
# Out:
#       period period_end_date                  compset_group  \
# 742   Weekly      2015-01-03  Luxury & Premium & Mainstream
# 119   Weekly      2015-01-03  Luxury & Premium & Mainstream
# 44    Weekly      2015-01-03  Luxury & Premium & Mainstream
# 644   Weekly      2015-01-03  Luxury & Premium & Mainstream
# 759   Weekly      2015-01-10  Luxury & Premium & Mainstream
# ...      ...             ...                            ...
# 72    Weekly      2023-09-09  Luxury & Premium & Mainstream
# 1509  Weekly      2023-09-16  Luxury & Premium & Mainstream
# 1447  Weekly      2023-09-16  Luxury & Premium & Mainstream
# 1536  Weekly      2023-09-16  Luxury & Premium & Mainstream
# 1067  Weekly      2023-09-16  Luxury & Premium & Mainstream
#
#                                    compset  \
# 742     US Softlines Analyst Interest List
# 119          Luxury & Premium & Mainstream
# 44                             Soft Luxury
# 644   Global Luxury Analysts Interest List
# ...

# %%
df[(df['business_entity_doing_business_as_name'] == '24S')].sort_values(by='period_end_date')
# Out:
#         period period_end_date   compset_group  \
# 239841  Weekly      2017-05-06  Apparel Retail
# 240025  Weekly      2017-05-06  Apparel Retail
# 239828  Weekly      2017-05-06  Apparel Retail
# 239152  Weekly      2017-05-06  Apparel Retail
# 240403  Weekly      2017-05-13  Apparel Retail
# ...        ...             ...             ...
# 239838  Weekly      2023-09-09  Apparel Retail
# 239331  Weekly      2023-09-16  Apparel Retail
# 239545  Weekly      2023-09-16  Apparel Retail
# 239866  Weekly      2023-09-16  Apparel Retail
# 239654  Weekly      2023-09-16  Apparel Retail
#
#                                    compset  \
# 239841            Ecommerce Apparel Retail
# 240025  US Softlines Analyst Interest List
# 239828     Ecommerce Luxury Apparel Retail
# 239152                      Apparel Retail
# 240403                      Apparel Retail
# ...                                    ...
# 239838     Ecommerce Luxury Apparel Retail
# ...
